# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\SOOSAN SHABNAM\OneDrive\Desktop\house prices\qwerty\kc_house_data.csv")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df=df.drop(["id","date"],axis=1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.hist(bins = 50, figsize = (20, 15))
# Out:
# array([[<AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>,
#         <AxesSubplot:title={'center':'sqft_living'}>],
#        [<AxesSubplot:title={'center':'sqft_lot'}>,
#         <AxesSubplot:title={'center':'floors'}>,
#         <AxesSubplot:title={'center':'waterfront'}>,
#         <AxesSubplot:title={'center':'view'}>],
#        [<AxesSubplot:title={'center':'condition'}>,
#         <AxesSubplot:title={'center':'grade'}>,
#         <AxesSubplot:title={'center':'sqft_above'}>,
#         <AxesSubplot:title={'center':'sqft_basement'}>],
#        [<AxesSubplot:title={'center':'yr_built'}>,
#         <AxesSubplot:title={'center':'yr_renovated'}>,
#         <AxesSubplot:title={'center':'zipcode'}>,
#         <AxesSubplot:title={'center':'lat'}>],
#        [<AxesSubplot:title={'center':'long'}>,
#         <AxesSubplot:title={'center':'sqft_living15'}>,
# ...

# %%
sns.scatterplot(data=df, x='sqft_living',y='price')
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df, x='bedrooms',y='price')
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df, x='bathrooms',y='price')
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='price'>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=df, x="bedrooms", y="price", hue="bathrooms")
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
sqft=[feature for feature in df if 'sqft' in feature]
yr=[feature for feature in df if 'yr' in feature]
print(sqft)
print(yr)
# Out:
# ['sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement', 'sqft_living15', 'sqft_lot15']
# ['yr_built', 'yr_renovated']

# %%
df['yr_renovated'].unique()
# Out:
# array([   0, 1991, 2002, 2010, 1999, 1992, 2013, 1994, 1978, 2005, 2008,
#        2003, 1984, 1954, 2014, 2011, 1974, 1983, 1945, 1990, 1988, 1957,
#        1977, 1981, 1995, 2000, 1998, 1970, 1989, 2004, 1986, 2009, 2007,
#        1987, 1973, 2006, 1985, 2001, 1980, 1971, 1979, 1997, 1950, 1969,
#        1948, 2015, 1968, 2012, 1963, 1951, 1993, 1962, 1996, 1972, 1953,
#        1955, 1982, 1956, 1940, 1976, 1946, 1975, 1958, 1964, 1959, 1960,
#        1967, 1965, 1934, 1944], dtype=int64)

# %%
data=df.copy()
data['diff']=data['yr_built']-data['yr_renovated']
sns.scatterplot(data=data, x='diff',y='price')
# Out:
# <AxesSubplot:xlabel='diff', ylabel='price'>

# %%
discrete_feature=[feature for feature in df if len(df[feature].unique())<35 and feature not in yr]
print(discrete_feature)
# Out:
# ['bedrooms', 'bathrooms', 'floors', 'waterfront', 'view', 'condition', 'grade']

# %%
for feature in discrete_feature:
    data.groupby(feature)['price'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel("price")
    plt.show()

# %%
cont=df.drop(['bedrooms', 'bathrooms', 'floors', 'waterfront', 'view', 'condition', 'grade'],axis=1)
for feature in cont:
    cont[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("count")
    plt.show()

# %%
for feature in cont:
    data=df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        plt.scatter(data[feature],data['price'])
        plt.xlabel(feature)
        plt.ylabel('price')
        plt.show()
# Out:
# c:\users\soosan shabnam\appdata\local\programs\python\python39\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# # outliers

# %%
for feature in cont:
    data=df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.show()
# Out:
# c:\users\soosan shabnam\appdata\local\programs\python\python39\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
categorical_feature=['bedrooms', 'bathrooms', 'floors', 'waterfront', 'view', 'condition', 'grade']
for feature in categorical_feature:
    print("The feature is {} and unique count is {}".format(feature,df[feature].unique()))
# Out:
# The feature is bedrooms and unique count is [ 3  2  4  5  1  6  7  0  8  9 11 10 33]
# The feature is bathrooms and unique count is [1.   2.25 3.   2.   4.5  1.5  2.5  1.75 2.75 3.25 4.   3.5  0.75 4.75
#  5.   4.25 3.75 0.   1.25 5.25 6.   0.5  5.5  6.75 5.75 8.   7.5  7.75
#  6.25 6.5 ]
# The feature is floors and unique count is [1.  2.  1.5 3.  2.5 3.5]
# The feature is waterfront and unique count is [0 1]
# The feature is view and unique count is [0 3 4 2 1]
# The feature is condition and unique count is [3 5 4 1 2]
# The feature is grade and unique count is [ 7  6  8 11  9  5 10 12  4  3 13  1]

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
for feature in sqft:
    df[feature]=df[feature].replace(0,1)
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              1      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              1      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              1      1987             0
#
# ...

# %%
for feature in sqft:
    df[feature]=np.log(df[feature])
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00     7.073270  8.639411     1.0           0
# 1  538000.0         3       2.25     7.851661  8.887653     2.0           0
# 2  180000.0         2       1.00     6.646391  9.210340     1.0           0
# 3  604000.0         4       3.00     7.580700  8.517193     1.0           0
# 4  510000.0         3       2.00     7.426549  8.997147     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7    7.073270       0.000000      1955             0
# 1     0          3      7    7.682482       5.991465      1951          1991
# 2     0          3      6    6.646391       0.000000      1933             0
# 3     0          5      7    6.956545       6.813445      1965             0
# 4     0          3      8    7.426549       0.000000      1987             0
#
# ...

# %%
df['waterfront'].value_counts()
# Out:
# 0    21450
# 1      163
# Name: waterfront, dtype: int64

# %%
df=df.drop('waterfront',axis=1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  view  \
# 0  221900.0         3       1.00     7.073270  8.639411     1.0     0
# 1  538000.0         3       2.25     7.851661  8.887653     2.0     0
# 2  180000.0         2       1.00     6.646391  9.210340     1.0     0
# 3  604000.0         4       3.00     7.580700  8.517193     1.0     0
# 4  510000.0         3       2.00     7.426549  8.997147     1.0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7    7.073270       0.000000      1955             0
# 1          3      7    7.682482       5.991465      1951          1991
# 2          3      6    6.646391       0.000000      1933             0
# 3          5      7    6.956545       6.813445      1965             0
# 4          3      8    7.426549       0.000000      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# 0    98178  47.5112 -122.257       7.200425    8.639411
# ...

# %%
X=df.drop("price",axis=1)
y=df["price"]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=101)

# %%
def run_model(model,X_train,X_test,y_train,y_test):
    model.fit(X_train, y_train)
    preds=model.predict(X_test)
    from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score
    rmse=np.sqrt(mean_squared_error(y_test,preds))
    mae=mean_absolute_error(y_test,preds)
    print(f'MAE IS {mae}')
    print(f'RMSE IS {rmse}')
    sns.scatterplot(x=y_test,y=preds) 
    
    print("Score on Testing Set: ", model.score(X_test,y_test))

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
run_model(model,X_train,X_test,y_train,y_test)
# Out:
# MAE IS 122247.66393083498
# RMSE IS 199252.7824167225
# Score on Testing Set:  0.7089991568158225
